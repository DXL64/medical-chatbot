# %%
from source.medical_agent import MedicalAgent

agent = MedicalAgent()

# %%
img = agent.medical_graph.visualize_graph("image")

# %%
type(img)
# Out:
# IPython.core.display.Image

# %%
display(img)

# %%
from IPython.display import Image


# Save the image to a file
with open("saved_image.png", "wb") as f:
    f.write(img.data)
